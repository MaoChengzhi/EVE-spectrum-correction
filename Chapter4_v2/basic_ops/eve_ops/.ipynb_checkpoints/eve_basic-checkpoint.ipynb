# %%
import numpy as np
import cupy as cp
import cupyx.scipy.signal as signal
import scipy
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots

from astropy.modeling import models, fitting
import astropy.units as u
from astropy import constants as const
from astropy.stats import gaussian_sigma_to_fwhm

import datetime
import pickle
import importlib
import json
import time
import glob
from skimage.metrics import structural_similarity as ssim

from gaussian_fit_eve import gaussian_fit_eve
from data.eve_const import  wavelength_list_eve

# %% [markdown]
# ## orginal
#
# before fitting

# %%
with open('./data/original_data.pkl', 'wb') as file:
    pickle.dump(original_df, file)

# %%
with open('./data/original_data.pkl', 'rb') as file:
    original_df = pickle.load(file)

# %%
# original_df  irradiance column is array, I want to replace negative in the array with np.nan
def replace_negative_one(x):
    # x[x<0]=np.nan
    x=np.where(x<0, np.nan, x)
    return x

original_df['irradiance'] = original_df['irradiance'].apply(replace_negative_one)

# %%
original_df[-100:]
# Out:
#                         time  \
# 12996620 2014-12-31 22:43:29
# 12996621 2014-12-31 22:43:39
# 12996622 2014-12-31 22:43:49
# 12996623 2014-12-31 22:43:59
# 12996624 2014-12-31 22:44:09
# ...                      ...
# 12996715 2014-12-31 22:59:19
# 12996716 2014-12-31 22:59:29
# 12996717 2014-12-31 22:59:39
# 12996718 2014-12-31 22:59:49
# 12996719 2014-12-31 22:59:59
#
#                                                  irradiance
# 12996620  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 12996621  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 12996622  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 12996623  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 12996624  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# ...                                                     ...
# 12996715  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 12996716  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 12996717  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# ...

# %%
irradiance_array=np.array(original_df['irradiance'].tolist())
irradiance_array
# Out:
# array([[2.6092563e-05, 1.3120413e-04, 4.6210643e-04, ..., 1.9184785e-04,
#         7.4447729e-05, 5.0256080e-05],
#        [2.4313835e-05, 1.2673343e-04, 4.5906374e-04, ..., 1.9270962e-04,
#         7.4217343e-05, 5.2136638e-05],
#        [2.5151077e-05, 1.2693906e-04, 4.5360095e-04, ..., 1.9306244e-04,
#         7.5396048e-05, 4.9857281e-05],
#        ...,
#        [          nan,           nan,           nan, ...,           nan,
#                   nan,           nan],
#        [          nan,           nan,           nan, ...,           nan,
#                   nan,           nan],
#        [          nan,           nan,           nan, ...,           nan,
#                   nan,           nan]], dtype=float32)

# %%
len(original_df)
# Out:
# 12996720

# %%
np.arange(0,len(original_df),3)
# Out:
# array([       0,        3,        6, ..., 12996711, 12996714, 12996717])

# %%
original_df['time'][0].date()
# Out:
# datetime.date(2010, 4, 30)

# %%
# Create a 6x4 array with random values
array_data = np.random.rand(7, 4)

# Set the last 3 rows to np.nan
array_data[-3:-1, :] = np.nan
# array_data[7,:]=[1,2,3]

print(array_data)

plt.imshow(array_data,aspect=0.1)
# Out:
# [[0.73952567 0.7629023  0.24643908 0.4147057 ]
#  [0.14112814 0.75135864 0.38709137 0.63998986]
#  [0.00804572 0.68682927 0.38439735 0.59627366]
#  [0.69419167 0.5117608  0.06595924 0.20403664]
#  [       nan        nan        nan        nan]
#  [       nan        nan        nan        nan]
#  [0.58068277 0.77931928 0.7294925  0.56726035]]

# %%
plt.imshow(irradiance_array,aspect=6e-7,)

# %%
np.isnan(irradiance_array)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
plt.imshow(np.isnan(irradiance_array),aspect=6e-7,)

# %%
plt.imshow(np.isnan(concatenated_array),aspect=6e-6,)
plt.colorbar()

# %%
np.isnan(concatenated_array).sum()/1e7
# Out:
# 4.2869523

# %%
irradiance_array.shape
# Out:
# (12996720, 12)

# %%
# Define the number of rows with np.nan to add (3000000 rows in this example)
num_nan_rows = 30000000

# Create an array of np.nan with the desired shape (num_nan_rows, 12)
nan_array = np.full((num_nan_rows, 12), np.nan)

# Concatenate the np.nan array with the original irradiance_array
concatenated_array = np.concatenate((irradiance_array, nan_array), axis=0)

# %%
concatenated_array
# Out:
# array([[2.60925626e-05, 1.31204128e-04, 4.62106429e-04, ...,
#         1.91847852e-04, 7.44477293e-05, 5.02560797e-05],
#        [2.43138347e-05, 1.26733430e-04, 4.59063740e-04, ...,
#         1.92709616e-04, 7.42173434e-05, 5.21366383e-05],
#        [2.51510774e-05, 1.26939063e-04, 4.53600951e-04, ...,
#         1.93062442e-04, 7.53960485e-05, 4.98572808e-05],
#        ...,
#        [           nan,            nan,            nan, ...,
#                    nan,            nan,            nan],
#        [           nan,            nan,            nan, ...,
#                    nan,            nan,            nan],
#        [           nan,            nan,            nan, ...,
#                    nan,            nan,            nan]])

# %%
concatenated_array.shape
# Out:
# (42996720, 12)

# %%
plt.imshow(concatenated_array,aspect=6e-7,)
# Out:
# C:\Users\14902\anaconda3\envs\sdo2022\lib\site-packages\matplotlib\image.py:180: UserWarning: Data with more than 2**24 rows cannot be accurately displayed. Downsampling to less than 2**24 rows before displaying. To remove this warning, manually downsample your data.
#   warnings.warn(msg.format(n='2**24 rows'))

# %%
fig,ax=plt.subplots()
sc=ax.imshow(irradiance_array,aspect=6e-7,origin='lower')
fig.colorbar(sc,shrink=0.8)

# set x tick label using wavelength_list_eve
ax.set_xticks(np.arange(0,len(wavelength_list_eve),3))
ax.set_xticklabels(wavelength_list_eve[::3])

# set y tick label using date in time, set 5 ticks in total
ax.set_yticks(np.linspace(0,len(original_df)-1,5))
ax.set_yticklabels([original_df['time'][i].date() for i in np.linspace(0,len(original_df)-1,5).astype(int)])
# Out:
# [Text(0, 0.0, '2010-04-30'),
#  Text(0, 3249179.75, '2011-05-19'),
#  Text(0, 6498359.5, '2012-06-03'),
#  Text(0, 9747539.25, '2013-06-15'),
#  Text(0, 12996719.0, '2014-12-31')]

# %% [markdown]
# ## 10s

# %%
time_list = original_df.index.tolist()

# %%
mean_10s=[]
stddev_10s=[]
amp_10s=[]
i=0
for key in original_df.index:
    amp,cen,stddev=gaussian_fit_eve(wavelength_list_eve,original_df.loc[key]['irradiance'])
    amp_10s.append(amp)
    stddev_10s.append(stddev)
    cen_10s.append(cen)
    # if not np.isnan(cen):
    # print(key,cen)
    i=i+1
    if(i%8640==0):
        print(key,cen)

# %% [markdown]
# ## SSIM

# %%
def calculate_ssim(image1, image2):
    # Ensure that the images are in the range [0, 255] and are of dtype 'uint8'
    image1 = np.clip(image1, 0, 255).astype(np.uint8)
    image2 = np.clip(image2, 0, 255).astype(np.uint8)

    # Calculate SSIM between the two images
    ssim_score, _ = ssim(image1, image2, full=True)

    return ssim_score

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample images (replace these with your actual image arrays)
image_array1 = np.random.rand(256, 256)  # Random 256x256 image
image_array2 = np.random.rand(256, 256)  # Another random 256x256 image
# image_array2=image_array1+90.9*np.random.rand(256, 256)



# Calculate SSIM
ssim_score = calculate_ssim(image_array1, image_array2)
print(f"SSIM Score: {ssim_score}")

# Display the images (optional)
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(image_array1, cmap='gray')
plt.title('Image 1')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_array2, cmap='gray')
plt.title('Image 2')
plt.axis('off')

plt.show()
# Out:
# SSIM Score: 1.0

# %%
np.random.rand(256, 256)
# Out:
# array([[0.26357884, 0.40362785, 0.56709275, ..., 0.18279851, 0.83317964,
#         0.88304166],
#        [0.28639447, 0.27803139, 0.26132173, ..., 0.95983273, 0.55295077,
#         0.10809489],
#        [0.40848966, 0.39125119, 0.946393  , ..., 0.21972004, 0.32201844,
#         0.82652823],
#        ...,
#        [0.57522439, 0.3479289 , 0.30062482, ..., 0.88403622, 0.16401643,
#         0.49344341],
#        [0.31479796, 0.91145438, 0.89608286, ..., 0.34623173, 0.11346879,
#         0.74700512],
#        [0.69433729, 0.59284278, 0.84739493, ..., 0.5442126 , 0.10049913,
#         0.3030925 ]])

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim

# Sample images (replace these with your actual image arrays)
image_array1 = np.random.rand(256, 256) * 255  # Random 256x256 image
image_array2 = np.random.rand(256, 256) * 255  # Another random 256x256 image

def calculate_ssim(image1, image2):
    # Ensure that the images are in the range [0, 255] and are of dtype 'uint8'
    image1 = np.clip(image1, 0, 255).astype(np.uint8)
    image2 = np.clip(image2, 0, 255).astype(np.uint8)

    # Calculate SSIM between the two images
    ssim_score, _ = ssim(image1, image2, full=True)

    return ssim_score

# Calculate SSIM
ssim_score = calculate_ssim(image_array1, image_array2)
print(f"SSIM Score: {ssim_score}")

# Display the images (optional)
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(image_array1, cmap='gray')
plt.title('Image 1')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_array2, cmap='gray')
plt.title('Image 2')
plt.axis('off')

plt.show()
# Out:
# SSIM Score: 0.008695298102998655

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a 1000x1000 array with random values for the first 800 rows
array_data = np.random.rand(8000, 1000)

# Set the last 200 rows to np.nan
array_data[-200:, :] = np.nan

# Visualize the array using imshow
plt.imshow(array_data, cmap='viridis',aspect=0.1)
plt.colorbar()
plt.title("imshow of the array with np.nan")
plt.show()

# Visualize the array using matshow
plt.matshow(array_data, cmap='viridis')
plt.colorbar()
plt.title("matshow of the array with np.nan")
plt.show()

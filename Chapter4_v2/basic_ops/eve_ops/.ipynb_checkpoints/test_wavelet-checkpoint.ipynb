# %%
# test.py
import numpy as np
from do_wavelet import do_wavelet

t=np.linspace(0,1,1000)
dt=t[1]-t[0]
sst=np.sin(2*np.pi*50*t)+np.exp(t)


do_wavelet(sst,dt,unit='Second')
# Out:
# Data variance =  0.7319463717102126
# d:\py_repo\EVE-spectrum-correction\Chapter4_v2\basic_ops\eve_ops\do_wavelet.py:188: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ([], array([], dtype=float64), array([], dtype=float64))

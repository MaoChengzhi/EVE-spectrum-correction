# %%
from std_pixel_to_world import std_pixel_to_world
from my_pixel_to_world import my_pixel_to_world
import sunpy
import numpy as np
import matplotlib.pyplot as plt
from aiapy.calibrate import register, update_pointing, normalize_exposure

# %%
AIA_filename = "..//data//AIA//aia_lev1_304a_2011_01_27t22_58_56_12z_image_lev1.fits"
m_aia = sunpy.map.Map(AIA_filename)
m_normalized = normalize_exposure(register(update_pointing(m_aia)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 AIA_filename = "..//data//AIA//aia_lev1_304a_2011_01_27t22_58_56_12z_image_lev1.fits"
# ----> 2 m_aia = sunpy.map.Map(AIA_filename)
#       3 m_normalized = normalize_exposure(register(update_pointing(m_aia)))
#
# File c:\Users\14902\anaconda3\envs\sdo2022\lib\site-packages\sunpy\map\map_factory.py:318, in MapFactory.__call__(self, composite, sequence, silence_errors, *args, **kwargs)
#     292 def __call__(self, *args, composite=False, sequence=False, silence_errors=False, **kwargs):
#     293     """ Method for running the factory. Takes arbitrary arguments and
#     294     keyword arguments and passes them to a sequence of pre-registered types
#     295     to determine which is the correct Map-type to build.
#    (...)
#     316     as `memmap` for FITS files.
#     317     """
# --> 318     data_header_pairs = self._parse_args(*args, silence_errors=silence_errors, **kwargs)
#     319     new_maps = list()
#     321     # Loop over each registered type and check to see if WidgetType
#     322     # matches the arguments.  If it does, use that type.
#
# File c:\Users\14902\anaconda3\envs\sdo2022\lib\site-packages\sunpy\map\map_factory.py:244, in MapFactory._parse_args(self, silence_errors, *args, **kwargs)
#     242 for arg in args:
#     243     try:
# --> 244         data_header_pairs += self._parse_arg(arg, **kwargs)
#     245     except NoMapsInFileError as e:
#     246         if not silence_errors:
#
# File c:\Users\14902\anaconda3\envs\sdo2022\lib\site-packages\sunpy\util\functools.py:18, in seconddispatch.<locals>.wrapper(*args, **kwargs)
#      17 def wrapper(*args, **kwargs):
# ---> 18     return dispatcher.dispatch(args[1].__class__)(*args, **kwargs)
#
# File c:\Users\14902\anaconda3\envs\sdo2022\lib\site-packages\sunpy\map\map_factory.py:290, in MapFactory._parse_path(self, arg, **kwargs)
#     288 @_parse_arg.register(pathlib.Path)
#     289 def _parse_path(self, arg, **kwargs):
# --> 290     return parse_path(arg, self._read_file, **kwargs)
#
# File c:\Users\14902\anaconda3\envs\sdo2022\lib\site-packages\sunpy\util\io.py:44, in parse_path(path, f, **kwargs)
#      42     return read_files
#      43 else:
# ---> 44     raise ValueError(f'Did not find any files at {path}')
#
# ValueError: Did not find any files at ..\data\AIA\aia_lev1_304a_2011_01_27t22_58_56_12z_image_lev1.fits

# %%
image_shape_x,image_shape_y=m_normalized.data.shape
approximation_points_num=20
x_pixel_list=np.linspace(0,image_shape_x,approximation_points_num)
y_pixel_list=np.linspace(0,image_shape_y,approximation_points_num)
standard_Tx_list=np.zeros((approximation_points_num**2,1))
standard_Ty_list=np.zeros((approximation_points_num**2,1))

point_list=np.zeros((approximation_points_num**2, 2))

# %%
x_pixel_list
# Out:
# array([   0.        ,  215.57894737,  431.15789474,  646.73684211,
#         862.31578947, 1077.89473684, 1293.47368421, 1509.05263158,
#        1724.63157895, 1940.21052632, 2155.78947368, 2371.36842105,
#        2586.94736842, 2802.52631579, 3018.10526316, 3233.68421053,
#        3449.26315789, 3664.84210526, 3880.42105263, 4096.        ])

# %%
i=0
for x_pixel in x_pixel_list:
    for y_pixel in y_pixel_list:
        point_list[i]=x_pixel,y_pixel
        standard_Tx_list[i],standard_Ty_list[i]=std_pixel_to_world(x_pixel,y_pixel)
        i+=1

# %%
x_pixel_list
# Out:
# array([   0.        ,  215.57894737,  431.15789474,  646.73684211,
#         862.31578947, 1077.89473684, 1293.47368421, 1509.05263158,
#        1724.63157895, 1940.21052632, 2155.78947368, 2371.36842105,
#        2586.94736842, 2802.52631579, 3018.10526316, 3233.68421053,
#        3449.26315789, 3664.84210526, 3880.42105263, 4096.        ])

# %%
standard_Tx_list
# Out:
# array([[-0.00598775],
#        [-0.00598631],
#        [-0.00598487],
#        [-0.00598344],
#        [-0.005982  ],
#        [-0.00598056],
#        [-0.00597912],
#        [-0.00597768],
#        [-0.00597624],
#        [-0.0059748 ],
#        [-0.00597336],
#        [-0.00597193],
#        [-0.00597049],
#        [-0.00596905],
#        [-0.00596761],
#        [-0.00596617],
#        [-0.00596473],
#        [-0.00596329],
#        [-0.00596186],
#        [-0.00596042],
#        [-0.00536051],
#        [-0.00535907],
#        [-0.00535763],
#        [-0.00535619],
#        [-0.00535475],
#        [-0.00535331],
#        [-0.00535187],
#        [-0.00535044],
#        [-0.005349  ],
#        [-0.00534756],
#        [-0.00534612],
#        [-0.00534468],
#        [-0.00534324],
#        [-0.0053418 ],
#        [-0.00534037],
#        [-0.00533893],
#        [-0.00533749],
#        [-0.00533605],
#        [-0.00533461],
#        [-0.00533317],
#        [-0.00473326],
#        [-0.00473182],
#        [-0.00473038],
#        [-0.00472894],
#        [-0.0047275 ],
#        [-0.00472606],
#        [-0.00472463],
#        [-0.00472319],
#        [-0.00472175],
#        [-0.00472031],
#        [-0.00471887],
#        [-0.00471743],
#        [-0.00471599],
#        [-0.00471456],
#        [-0.00471312],
#        [-0.00471168],
#        [-0.00471024],
#        [-0.0047088 ],
#        [-0.00470736],
#        [-0.00470592],
#        [-0.00410601],
#        [-0.00410457],
#        [-0.00410313],
#        [-0.00410169],
#        [-0.00410025],
#        [-0.00409881],
#        [-0.00409737],
#        [-0.00409594],
#        [-0.0040945 ],
#        [-0.00409306],
#        [-0.00409162],
#        [-0.00409018],
#        [-0.00408874],
#        [-0.0040873 ],
#        [-0.00408586],
#        [-0.00408443],
#        [-0.00408299],
#        [-0.00408155],
#        [-0.00408011],
#        [-0.00407867],
#        [-0.00347875],
#        [-0.00347731],
#        [-0.00347587],
#        [-0.00347443],
#        [-0.003473  ],
#        [-0.00347156],
#        [-0.00347012],
#        [-0.00346868],
#        [-0.00346724],
#        [-0.0034658 ],
#        [-0.00346436],
#        [-0.00346292],
#        [-0.00346149],
#        [-0.00346005],
#        [ 0.00469147],
#        [ 0.0046929 ],
#        [ 0.00469434],
#        [ 0.00469578],
#        [ 0.00469722],
#        [ 0.00469866],
#        [ 0.0047001 ],
#        [ 0.00470154],
#        [ 0.00470298],
#        [ 0.00530289],
#        [ 0.00530433],
#        [ 0.00530577],
#        [ 0.00530721],
#        [ 0.00530864],
#        [ 0.00531008],
#        [ 0.00531152],
#        [ 0.00531296],
#        [ 0.0053144 ],
#        [ 0.00531584],
#        [ 0.00531728],
#        [ 0.00531871],
#        [ 0.00532015],
#        [ 0.00532159],
#        [ 0.00532303],
#        [ 0.00532447],
#        [ 0.00532591],
#        [ 0.00532735],
#        [ 0.00532879],
#        [ 0.00533022],
#        [ 0.00593013],
#        [ 0.00593157],
#        [ 0.00593301],
#        [ 0.00593445],
#        [ 0.00593589],
#        [ 0.00593733],
#        [ 0.00593877],
#        [ 0.0059402 ],
#        [ 0.00594164],
#        [ 0.00594308],
#        [ 0.00594452],
#        [ 0.00594596],
#        [ 0.0059474 ],
#        [ 0.00594884],
#        [ 0.00595028],
#        [ 0.00595171],
#        [ 0.00595315],
#        [ 0.00595459],
#        [ 0.00595603],
#        [ 0.00595747]])

# %%
point_x_list=point_list[:,0]
point_y_list=point_list[:,1]
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter(point_x_list, point_y_list, standard_Tx_list)

# %%
point_x_list=point_list[:,0]
point_y_list=point_list[:,1]
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter(point_x_list, point_y_list, standard_Ty_list)

# %% [markdown]
# ## check

# %%
# %%     std_pixel_to_world            VS          my_pixel_to_world
from std_pixel_to_world import std_pixel_to_world
from my_pixel_to_world import my_pixel_to_world
import random
import math
import matplotlib.pyplot as plt
import numpy as np


# %%
test_num = 100
std_Tx, std_Ty, my_Tx, my_Ty = np.zeros((test_num,)), np.zeros(
    (test_num,)), np.zeros((test_num,)), np.zeros((test_num,))
pixel_x, pixel_y = np.zeros((test_num,)), np.zeros((test_num,))
error = 0
for i in range(test_num):
    pixel_x[i] = random.randrange(0, 4096)
    pixel_y[i] = random.randrange(0, 4096)
    std_Tx[i], std_Ty[i] = std_pixel_to_world(pixel_x[i], pixel_y[i])
    my_Tx[i], my_Ty[i] = my_pixel_to_world(pixel_x[i], pixel_y[i])
    # print(abs(1-my_Tx/std_Tx), abs(1-my_Ty/std_Ty))
    if max(abs(1-my_Tx[i]/std_Tx[i]), abs(1-my_Ty[i]/std_Ty[i])) > error:
        error = max(abs(1-my_Tx[i]/std_Tx[i]), abs(1-my_Ty[i]/std_Ty[i]))
print(error)


# %%
fig1 = plt.figure()
ax1 = plt.axes(projection='3d')
ax1.scatter(pixel_x, pixel_y, std_Tx, color="red", marker='o', s=100)
ax1.scatter(pixel_x, pixel_y, my_Tx, color="blue", marker='+', s=500)

fig2 = plt.figure()
ax2 = plt.axes(projection='3d')
ax2.scatter(pixel_x, pixel_y, std_Ty, color="red", marker='o', s=100)
ax2.scatter(pixel_x, pixel_y, my_Ty, color="blue", marker='+', s=500)
# Out:
# 8.000090656490322e-05
